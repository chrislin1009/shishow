# %% [markdown]
# <a href="https://colab.research.google.com/github/chrislin1009/shishow/blob/main/%E3%80%8CEX03_03_%E7%A9%BA%E6%B0%A3%E5%93%81%E8%B3%AA%E6%8C%87%E6%A8%99(AQI)_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = 'https://data.moenv.gov.tw/api/v2/aqx_p_432?api_key=9e565f9a-84dd-4e79-9097-d403cae1ea75&limit=1000&sort=ImportDate%20desc&format=CSV'
df = pd.read_csv(url)
df.head()
# Out:
#   sitename county  aqi pollutant status  so2    co  o3  o3_8hr  pm10  ...  \
# 0       基隆    基隆市   58     臭氧八小時     普通  1.6  0.14  56      57    21  ...
# 1       汐止    新北市   56     細懸浮微粒     普通  1.5  0.13  54      51    25  ...
# 2       新店    新北市   49       NaN     良好  1.3  0.17  54      53    22  ...
# 3       土城    新北市   65     細懸浮微粒     普通  1.6  0.18  57      55    29  ...
# 4       板橋    新北市   49       NaN     良好  2.1  0.21  56      53    26  ...
#
#    wind_speed  wind_direc          publishtime  co_8hr pm2.5_avg pm10_avg  \
# 0           2          87  2025/05/30 15:00:00     0.1       9.8       21
# 1         2.6          26  2025/05/30 15:00:00     0.1      14.2       21
# 2         2.5          29  2025/05/30 15:00:00     0.1      12.2       22
# 3         3.2          31  2025/05/30 15:00:00     0.2      17.5       24
# 4         3.4          42  2025/05/30 15:00:00     0.2      10.5       22
#
#   so2_avg   longitude   latitude  siteid
# 0     1.0  121.760056  25.129167       1
# 1     0.0  121.640810  25.066240       2
# 2     0.0  121.537778  24.977222       4
# 3     0.0  121.451861  24.982528       5
# 4     0.0  121.458667  25.012972       6
#
# [5 rows x 24 columns]

# %%
df = df[['sitename','county','pollutant','status','aqi']]

# %%
condition = df['aqi'] > 50
df[condition]
# Out:
#    sitename county pollutant status  aqi
# 0        基隆    基隆市     臭氧八小時     普通   58
# 1        汐止    新北市     細懸浮微粒     普通   56
# 3        土城    新北市     細懸浮微粒     普通   65
# 5        新莊    新北市     細懸浮微粒     普通   55
# 6        菜寮    新北市     細懸浮微粒     普通   57
# 7        林口    新北市     細懸浮微粒     普通   52
# 8        淡水    新北市     細懸浮微粒     普通   53
# 9        士林    臺北市     細懸浮微粒     普通   58
# 10       中山    臺北市     細懸浮微粒     普通   60
# 12       古亭    臺北市     細懸浮微粒     普通   55
# 13       松山    臺北市     細懸浮微粒     普通   52
# 14       大同    臺北市     細懸浮微粒     普通   59
# 15       桃園    桃園市     細懸浮微粒     普通   55
# 16       大園    桃園市     細懸浮微粒     普通   59
# 17       觀音    桃園市     細懸浮微粒     普通   52
# 18       平鎮    桃園市     臭氧八小時     普通   58
# 19       龍潭    桃園市     細懸浮微粒     普通   59
# 20       湖口    新竹縣     臭氧八小時     普通   58
# 22       新竹    新竹市     臭氧八小時     普通   61
# 23       頭份    苗栗縣     臭氧八小時     普通   54
# 27       沙鹿    臺中市     臭氧八小時     普通   51
# 32       線西    彰化縣      懸浮微粒     普通   60
# 33       二林    彰化縣      懸浮微粒     普通   57
# 39       臺西    雲林縣     臭氧八小時     普通   58
# 40       嘉義    嘉義市     細懸浮微粒     普通   52
# 64       三重    新北市     細懸浮微粒     普通   65
# 65       中壢    桃園市     細懸浮微粒     普通   59
# 67       永和    新北市     細懸浮微粒     普通   58
# 70       馬祖    連江縣     細懸浮微粒     普通   76
# 71       金門    金門縣     臭氧八小時     普通   77
# 72       馬公    澎湖縣     臭氧八小時     普通   74
# 74       麥寮    雲林縣     臭氧八小時     普通   51
# 75      富貴角    新北市     臭氧八小時     普通   74
# 76       大城    彰化縣     臭氧八小時     普通   71
# 83   新北(樹林)    新北市     臭氧八小時     普通   61

# %%
df['pollutant'].unique()
# Out:
# array(['臭氧八小時', '細懸浮微粒', nan, '懸浮微粒'], dtype=object)

# %%
condition = df['county'] == '高雄市'
df[condition]
# Out:
#    sitename county pollutant status  aqi
# 45       美濃    高雄市       NaN     良好   29
# 46       橋頭    高雄市       NaN     良好   40
# 47       仁武    高雄市       NaN     良好   27
# 48       鳳山    高雄市       NaN     良好   40
# 49       大寮    高雄市       NaN     良好   42
# 50       林園    高雄市       NaN     良好   29
# 51       楠梓    高雄市       NaN     良好   42
# 52       左營    高雄市       NaN     良好   28
# 53       前金    高雄市       NaN     良好   28
# 54       前鎮    高雄市       NaN     良好   23
# 55       小港    高雄市       NaN     良好   19
# 68       復興    高雄市       NaN     良好   22
# 79   高雄（湖內）    高雄市       NaN     良好   31

# %%
df.groupby('county')['aqi'].mean().sort_values(ascending=False)
# Out:
# county
# 金門縣    77.000000
# 連江縣    76.000000
# 澎湖縣    74.000000
# 新竹市    61.000000
# 基隆市    58.000000
# 新北市    57.833333
# 桃園市    57.000000
# 彰化縣    54.800000
# 臺北市    54.571429
# 新竹縣    53.000000
# 嘉義市    52.000000
# 苗栗縣    49.333333
# 雲林縣    49.000000
# 花蓮縣    49.000000
# 嘉義縣    43.500000
# 宜蘭縣    43.333333
# 臺南市    43.200000
# 臺中市    40.500000
# 臺東縣    40.000000
# 屏東縣    39.400000
# 高雄市    30.769231
# 南投縣    29.000000
# Name: aqi, dtype: float64
